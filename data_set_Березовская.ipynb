# %% [markdown]
# <a href="https://colab.research.google.com/github/plotsaf8/first/blob/main/data_set_%D0%91%D0%B5%D1%80%D0%B5%D0%B7%D0%BE%D0%B2%D1%81%D0%BA%D0%B0%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

import numpy as np
import pandas as pd
import re
import nltk
import string

##Чтение датасета с текстом
df = pd.read_csv("/content/kinopoisk-top250.csv", encoding='UTF8')
df.head(10)
# Out:
# ...
#    rating                              movie  year  country  rating_ball  \
# 0       0                 Побег из Шоушенка   1994      США        9.111
# 1       1                      Зеленая миля   1999      США        9.062
# 2       2                      Форрест Гамп   1994      США        8.913
# 3       3                   Список Шиндлера   1993      США        8.817
# 4       4                               1+1   2011  Франция        8.807
# 5       5                            Начало   2010      США        8.662
# 6       6                              Леон   1994  Франция        8.681
# 7       7                        Король Лев   1994      США        8.772
# 8       8                   Бойцовский клуб   1999      США        8.645
# 9       9  Иван Васильевич меняет профессию   1973     СССР        8.782
#
#                                             overview  \
# 0  Бухгалтер Энди Дюфрейн обвинён в убийстве собс...
# 1  Пол Эджкомб — начальник блока смертников в тюр...
# ...
